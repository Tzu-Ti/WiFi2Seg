# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
path = "/root/SSD/PiWiFi/NYCU/Env0/img/M3/1_posi/240506_194233/1714995801788506176_skeleton.npy"
output = np.load(path)
plt.figure(figsize=(15, 10))
for i in range(9):
    for j in range(9):
        idx = i*9+j
        plt.subplot(9, 9, idx+1)
        plt.axis('off')
        if idx == 78: break
        plt.imshow(output[idx], cmap='gray')

# %%
img_path = "/root/SSD/PiWiFi/NYCU/Env0/img/M3/1_posi/240506_194233/1714995801788506176.jpg"
img = plt.imread(img_path)
plt.imshow(img)
